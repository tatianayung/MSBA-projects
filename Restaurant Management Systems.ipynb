# %%
import random
import time;
import datetime
import tkinter.messagebox
from tkinter import *

# %%
root = Tk()
root.geometry("1350x750+0+0")
root.title("Restaurant Management Systems")
root.configure(background = 'Cadet Blue')

# %%
Tops = Frame(root, bg='Cadet Blue', bd=20, pady=5, relief=RIDGE)
Tops.pack(side=TOP)

lblTitle = Label(Tops, font=('arial', 60, 'bold'), text="Restaurant Management Systems", 
                 bd=21, bg='Cadet Blue', fg='Cornsilk',justify=CENTER)
lblTitle.grid(row=0, column=0)


ReceiptCal_F = Frame(root, bg='Powder Blue', bd=10, relief=RIDGE)
ReceiptCal_F.pack(side=RIGHT)

Cal_F=Frame(ReceiptCal_F, bg='Powder Blue', bd=3, relief=RIDGE)
Cal_F.pack(side=TOP)

ButtonsFrame=Frame(ReceiptCal_F, bg='Powder Blue', bd=6, relief=RIDGE)
ButtonsFrame.pack(side=BOTTOM)

ReceiptFrame=Frame(ReceiptCal_F, bg='Powder Blue', bd=4, relief=RIDGE)
ReceiptFrame.pack(side=BOTTOM)

#menu
MenuFrame = Frame(root, bg='Cadet Blue', bd=10, relief=RIDGE)
MenuFrame.pack(side=LEFT)

#inside menu frame:  changed cake to combos


Cost_F=Frame(MenuFrame, bg='Cadet Blue', bd=4)
Cost_F.pack(side=BOTTOM)

ColumnFrame_1=Frame(MenuFrame, bg='Cadet Blue', bd=10, relief=RIDGE)
ColumnFrame_1.pack(side=TOP)


ColumnFrame_2=Frame(MenuFrame, bg='Cadet Blue', bd=10, relief=RIDGE)
ColumnFrame_2.pack(side=TOP)


ColumnFrame_3=Frame(MenuFrame, bg='Cadet Blue', bd=10, relief=RIDGE)
ColumnFrame_3.pack(side=TOP)
#===========================Variable===========================
DateofOrder = StringVar()
Receipt_Ref = StringVar()
SubTotal = StringVar()
TotalCost = StringVar()

ColumnFrame_1 = StringVar()
ColumnFrame_2 = StringVar()
ColumnFrame_3 = StringVar()

# CostofArrozChino = StringVar()
# CostofChopSuey = StringVar()
# CostofEntradas = StringVar()
# CostofCombosPersonales = StringVar()

text_Input = StringVar()
operator =""

E_menu1 = StringVar()
E_menu2 = StringVar()
E_menu3 = StringVar()
E_menu4 = StringVar()
E_menu5 = StringVar()
E_menu6 = StringVar()
E_menu7 = StringVar()
E_menu8 = StringVar()
# E_menu9 = StringVar()
# E_menu10 = StringVar()
# E_menu11 = StringVar()
# E_menu12 = StringVar()
# E_menu13 = StringVar()
# E_menu14 = StringVar()
# E_menu15 = StringVar()
# E_menu16 = StringVar()
# E_menu17 = StringVar()
# E_menu18 = StringVar()
# E_menu19 = StringVar()

E_menu20 = StringVar()
E_menu21 = StringVar()
E_menu22 = StringVar()
E_menu23 = StringVar()
E_menu24 = StringVar()
E_menu25 = StringVar()
E_menu26 = StringVar()
E_menu27 = StringVar()
E_menu28 = StringVar()
E_menu29 = StringVar()
E_menu30 = StringVar()
E_menu31 = StringVar()
E_menu32 = StringVar()
E_menu33 = StringVar()
E_menu34 = StringVar()
E_menu35 = StringVar()
E_menu36 = StringVar()

E_menu101 = StringVar()
E_menu102 = StringVar()
E_menu103 = StringVar()
E_menu104 = StringVar()
E_menu105 = StringVar()
E_menu106 = StringVar()
E_menu107 = StringVar()
E_menu108 = StringVar()
E_menu109 = StringVar()
E_menu110 = StringVar()
E_menu111 = StringVar()
E_menu112 = StringVar()
#--- and set '0'----

E_menu1.set('0')
E_menu2.set('0')
E_menu3.set('0')
E_menu4.set('0')
E_menu5.set('0')
E_menu6.set('0')
E_menu7.set('0')
E_menu8.set('0')

E_menu20.set('0')
E_menu21.set('0')
E_menu22.set('0')
E_menu23.set('0')
E_menu24.set('0')
E_menu25.set('0')
E_menu26.set('0')
E_menu27.set('0')
E_menu28.set('0')
E_menu29.set('0')
E_menu30.set('0')
E_menu31.set('0')
E_menu32.set('0')
E_menu33.set('0')
E_menu34.set('0')
E_menu35.set('0')
E_menu36.set('0')

E_menu101.set('0')
E_menu102.set('0')
E_menu103.set('0')
E_menu104.set('0')
E_menu105.set('0')
E_menu106.set('0')
E_menu107.set('0')
E_menu108.set('0')
E_menu109.set('0')
E_menu110.set('0')
E_menu111.set('0')
E_menu112.set('0')



DateofOrder.set(time.strftime('%d/%m/%Y'))


#================= Exit button & Reset button =======================
def iExit():
    iExit =tkinter.messagebox.askyesno('Salir del sistema', 'Confirmar si quieres salir')
    if iExit > 0:
        root.destroy()
        return

# %%
def iReset():
    SubTotal.set("")
    TotalCost.set("")
    txtReceipt.delete("1.0", END)
    
    E_menu1.set('0')
    E_menu2.set('0')
    E_menu3.set('0')
    E_menu4.set('0')
    E_menu5.set('0')
    E_menu6.set('0')
    E_menu7.set('0')
    E_menu8.set('0')

    E_menu20.set('0')
    E_menu21.set('0')
    E_menu22.set('0')
    E_menu23.set('0')
    E_menu24.set('0')
    E_menu25.set('0')
    E_menu26.set('0')
    E_menu27.set('0')
    E_menu28.set('0')
    E_menu29.set('0')
    E_menu30.set('0')
    E_menu31.set('0')
    E_menu32.set('0')
    E_menu33.set('0')
    E_menu34.set('0')
    E_menu35.set('0')
    E_menu36.set('0')

    E_menu101.set('0')
    E_menu102.set('0')
    E_menu103.set('0')
    E_menu104.set('0')
    E_menu105.set('0')
    E_menu106.set('0')
    E_menu107.set('0')
    E_menu108.set('0')
    E_menu109.set('0')
    E_menu110.set('0')
    E_menu111.set('0')
    E_menu112.set('0')
    
    var1.set(0)
    var2.set(0)
    var3.set(0)
    var4.set(0)
    var5.set(0)
    var6.set(0)
    var7.set(0)
    var8.set(0)

    var20.set(0)
    var21.set(0)
    var22.set(0)
    var23.set(0)
    var24.set(0)
    var25.set(0)
    var26.set(0)
    var27.set(0)
    var28.set(0)
    
    var29.set(0)
    var30.set(0)
    var31.set(0)
    var32.set(0)
    var33.set(0)
    var34.set(0)
    var35.set(0)
    var36.set(0)
    
    var101.set(0)
    var102.set(0)
    var103.set(0)
    var104.set(0)
    var105.set(0)
    var106.set(0)
    var107.set(0)
    var108.set(0)
    var109.set(0)
    var110.set(0)
    var111.set(0)
    var112.set(0)

    txt_menu1.configure(state =DISABLED)    
    txt_menu2.configure(state =DISABLED)    
    txt_menu3.configure(state =DISABLED)   
    txt_menu4.configure(state =DISABLED)    
    txt_menu5.configure(state =DISABLED)    
    txt_menu6.configure(state =DISABLED)    
    txt_menu7.configure(state =DISABLED)    
    txt_menu8.configure(state =DISABLED)    
    txt_menu9.configure(state =DISABLED)    
    txt_menu10.configure(state =DISABLED)    
    txt_menu11.configure(state =DISABLED)    
    txt_menu12.configure(state =DISABLED)    
    txt_menu13.configure(state =DISABLED)    
    txt_menu14.configure(state =DISABLED)    
    txt_menu15.configure(state =DISABLED)    
    txt_menu16.configure(state =DISABLED)    
    txt_menu17.configure(state =DISABLED)    
    txt_menu18.configure(state =DISABLED)    
    txt_menu19.configure(state =DISABLED)    
    txt_menu20.configure(state =DISABLED)    
    txt_menu21.configure(state =DISABLED)    
    txt_menu22.configure(state =DISABLED)    
    txt_menu23.configure(state =DISABLED)    
    txt_menu24.configure(state =DISABLED)    
    txt_menu25.configure(state =DISABLED)    
    txt_menu26.configure(state =DISABLED)    
    txt_menu27.configure(state =DISABLED)    
    txt_menu28.configure(state =DISABLED)    
    txt_menu29.configure(state =DISABLED)    
    txt_menu30.configure(state =DISABLED)    
    txt_menu31.configure(state =DISABLED)   
    txt_menu32.configure(state =DISABLED)   
    txt_menu33.configure(state =DISABLED)   
    txt_menu34.configure(state =DISABLED)   
    txt_menu35.configure(state =DISABLED)   
    txt_menu36.configure(state =DISABLED)   
    txt_menu101.configure(state =DISABLED)   
    txt_menu102.configure(state =DISABLED)   
    txt_menu103.configure(state =DISABLED)   
    txt_menu104.configure(state =DISABLED)   
    txt_menu105.configure(state =DISABLED)   
    txt_menu106.configure(state =DISABLED)   
    txt_menu107.configure(state =DISABLED)   
    txt_menu108.configure(state =DISABLED)   
    txt_menu109.configure(state =DISABLED)   
    txt_menu110.configure(state =DISABLED)   
    txt_menu111.configure(state =DISABLED)   
    txt_menu112.configure(state =DISABLED)  


def iCostofItem():
    item1=float(E_menu1.get())
    item2=float(E_menu2.get())
    item3=float(E_menu3.get())
    item4=float(E_menu4.get())
    item5=float(E_menu5.get())
    item6=float(E_menu6.get())
    item7=float(E_menu7.get())
    item8=float(E_menu8.get())
    item20=float(E_menu20.get())
    item21=float(E_menu21.get())
    item22=float(E_menu22.get())
    item23=float(E_menu23.get())
    item24=float(E_menu24.get())
    item25=float(E_menu25.get())
    item26=float(E_menu26.get())
    item27=float(E_menu27.get())
    item28=float(E_menu28.get())
    item29=float(E_menu29.get())
    item30=float(E_menu30.get())
    item31=float(E_menu31.get())
    item32=float(E_menu32.get())
    item33=float(E_menu33.get())
    item34=float(E_menu34.get())
    item35=float(E_menu35.get())
    item36=float(E_menu36.get())
    item101=float(E_menu101.get())
    item102=float(E_menu102.get())
    item103=float(E_menu103.get())
    item104=float(E_menu104.get())
    item105=float(E_menu105.get())
    item106=float(E_menu106.get())
    item107=float(E_menu107.get())
    item108=float(E_menu108.get())
    item109=float(E_menu109.get())
    item110=float(E_menu110.get())
    item111=float(E_menu111.get())
    item112=float(E_menu112.get())

    PriceOfColumn_1 =(item1*3500)+ (item2 * 26000)+ (item3 * 23000)+ (item4 * 26000) + (item5 * 23000)+ (item6 * 7000)+ (item7 * 17000)+ (item8 * 13000)

    PriceOfColumn_2 =(item20 *28500)+ (item21 * 24500)+(item22 * 31500)+ (item23 * 33500)+(item24 * 28500)+(item25 * 26000)+(item26 * 26000)+ (item27 * 29000)+(item28 * 38500)+(item29 * 28000)+ (item30 * 28000)+ (item31 * 33000)+ (item32 * 39000)+ (item33 * 28000)+ (item34 * 38000)+ (item35 * 32000)+ (item36 * 24500)

    PriceOfColumn_3 =(item101 *10000)+ (item102 * 10000)+ (item103 * 10000)+ (item104 * 10000)+ (item105 * 10000)+ (item106 * 10000)+ (item107 * 10000)+ (item108 * 10000)+ (item109 * 10000)+ (item110 * 10000)+ (item111 * 10000)+ (item112 * 10000)

    SubTotalofitems = str('%.2f'%(PriceOfColumn_1 + PriceOfColumn_2 + PriceOfColumn_3))
    SubTotal.set(SubTotalofitems)
    TotalCostofitems = str('%.2f'%(PriceOfColumn_1 + PriceOfColumn_2 + PriceOfColumn_3))
    TotalCost.set(TotalCostofitems)

#----------------checkbooks-----------------
def chk_menu1():
    if (var1.get() == 1):
        txt_menu1.configure(state = NORMAL)
        txt_menu1.focus()
        txt_menu1.delete('0', END)
        E_menu1.set("")
    elif (var1.get() == 0):
        txt_menu1.configure(state = DISABLED)
        E_menu1.set('0')

def chk_menu2():
    if (var2.get() == 1):
        txt_menu2.configure(state = NORMAL)
        txt_menu2.focus()
        txt_menu2.delete('0', END)
        E_menu2.set("")
    elif (var2.get() == 0):
        txt_menu2.configure(state = DISABLED)
        E_menu2.set('0')
        
def chk_menu3():
    if (var3.get() == 1):
        txt_menu3.configure(state = NORMAL)
        txt_menu3.focus()
        txt_menu3.delete('0', END)
        E_menu3.set("")
    elif (var3.get() == 0):
        txt_menu3.configure(state = DISABLED)
        E_menu3.set('0')
        
def chk_menu4():
    if (var4.get() == 1):
        txt_menu4.configure(state = NORMAL)
        txt_menu4.focus()
        txt_menu4.delete('0', END)
        E_menu4.set("")
    elif (var4.get() == 0):
        txt_menu4.configure(state = DISABLED)
        E_menu4.set('0')

def chk_menu5():
    if (var5.get() == 1):
        txt_menu5.configure(state = NORMAL)
        txt_menu5.focus()
        txt_menu5.delete('0', END)
        E_menu5.set("")
    elif (var5.get() == 0):
        txt_menu5.configure(state = DISABLED)
        E_menu5.set('0')
        
def chk_menu6():
    if (var6.get() == 1):
        txt_menu6.configure(state = NORMAL)
        txt_menu6.focus()
        txt_menu6.delete('0', END)
        E_menu6.set("")
    elif (var6.get() == 0):
        txt_menu6.configure(state = DISABLED)
        E_menu6.set('0')

def chk_menu7():
    if (var1.get() == 1):
        txt_menu7.configure(state = NORMAL)
        txt_menu7.focus()
        txt_menu7.delete('0', END)
        E_menu7.set("")
    elif (var7.get() == 0):
        txt_menu7.configure(state = DISABLED)
        E_menu7.set('0')

def chk_menu8():
    if (var8.get() == 1):
        txt_menu8.configure(state = NORMAL)
        txt_menu8.focus()
        txt_menu8.delete('0', END)
        E_menu8.set("")
    elif (var8.get() == 0):
        txt_menu8.configure(state = DISABLED)
        E_menu8.set('0')

def chk_menu20():
    if (var20.get() == 1):
        txt_menu20.configure(state = NORMAL)
        txt_menu20.focus()
        txt_menu20.delete('0', END)
        E_menu20.set("")
    elif (var20.get() == 0):
        txt_menu20.configure(state = DISABLED)
        E_menu20.set('0')
        
def chk_menu21():
    if (var21.get() == 1):
        txt_menu21.configure(state = NORMAL)
        txt_menu21.focus()
        txt_menu21.delete('0', END)
        E_menu21.set("")
    elif (var21.get() == 0):
        txt_menu21.configure(state = DISABLED)
        E_menu21.set('0')
        
def chk_menu22():
    if (var22.get() == 1):
        txt_menu22.configure(state = NORMAL)
        txt_menu22.focus()
        txt_menu22.delete('0', END)
        E_menu22.set("")
    elif (var22.get() == 0):
        txt_menu22.configure(state = DISABLED)
        E_menu22.set('0')
        
def chk_menu23():
    if (var23.get() == 1):
        txt_menu23.configure(state = NORMAL)
        txt_menu23.focus()
        txt_menu23.delete('0', END)
        E_menu23.set("")
    elif (var23.get() == 0):
        txt_menu23.configure(state = DISABLED)
        E_menu23.set('0')
        
def chk_menu24():
    if (var24.get() == 1):
        txt_menu24.configure(state = NORMAL)
        txt_menu24.focus()
        txt_menu24.delete('0', END)
        E_menu24.set("")
    elif (var24.get() == 0):
        txt_menu24.configure(state = DISABLED)
        E_menu24.set('0')
        
def chk_menu25():
    if (var25.get() == 1):
        txt_menu25.configure(state = NORMAL)
        txt_menu25.focus()
        txt_menu25.delete('0', END)
        E_menu25.set("")
    elif (var25.get() == 0):
        txt_menu25.configure(state = DISABLED)
        E_menu25.set('0')


def chk_menu26():
    if (var26.get() == 1):
        txt_menu26.configure(state = NORMAL)
        txt_menu26.focus()
        txt_menu26.delete('0', END)
        E_menu26.set("")
    elif (var26.get() == 0):
        txt_menu26.configure(state = DISABLED)
        E_menu26.set('0')
        
def chk_menu27():
    if (var27.get() == 1):
        txt_menu27.configure(state = NORMAL)
        txt_menu27.focus()
        txt_menu27.delete('0', END)
        E_menu27.set("")
    elif (var27.get() == 0):
        txt_menu27.configure(state = DISABLED)
        E_menu27.set('0')
        
def chk_menu28():
    if (var28.get() == 1):
        txt_menu28.configure(state = NORMAL)
        txt_menu28.focus()
        txt_menu28.delete('0', END)
        E_menu28.set("")
    elif (var28.get() == 0):
        txt_menu28.configure(state = DISABLED)
        E_menu28.set('0')
        
def chk_menu29():
    if (var29.get() == 1):
        txt_menu29.configure(state = NORMAL)
        txt_menu29.focus()
        txt_menu29.delete('0', END)
        E_menu29.set("")
    elif (var29.get() == 0):
        txt_menu29.configure(state = DISABLED)
        E_menu29.set('0')
        
def chk_menu30():
    if (var30.get() == 1):
        txt_menu30.configure(state = NORMAL)
        txt_menu30.focus()
        txt_menu30.delete('0', END)
        E_menu30.set("")
    elif (var30.get() == 0):
        txt_menu30.configure(state = DISABLED)
        E_menu30.set('0')
        
def chk_menu31():
    if (var31.get() == 1):
        txt_menu31.configure(state = NORMAL)
        txt_menu31.focus()
        txt_menu31.delete('0', END)
        E_menu31.set("")
    elif (var31.get() == 0):
        txt_menu31.configure(state = DISABLED)
        E_menu31.set('0')
        
def chk_menu32():
    if (var32.get() == 1):
        txt_menu32.configure(state = NORMAL)
        txt_menu32.focus()
        txt_menu32.delete('0', END)
        E_menu32.set("")
    elif (var32.get() == 0):
        txt_menu32.configure(state = DISABLED)
        E_menu32.set('0')

def chk_menu33():
    if (var33.get() == 1):
        txt_menu33.configure(state = NORMAL)
        txt_menu33.focus()
        txt_menu33.delete('0', END)
        E_menu33.set("")
    elif (var33.get() == 0):
        txt_menu33.configure(state = DISABLED)
        E_menu33.set('0')
        
def chk_menu34():
    if (var34.get() == 1):
        txt_menu34.configure(state = NORMAL)
        txt_menu34.focus()
        txt_menu34.delete('0', END)
        E_menu34.set("")
    elif (var34.get() == 0):
        txt_menu34.configure(state = DISABLED)
        E_menu34.set('0')
        
def chk_menu35():
    if (var35.get() == 1):
        txt_menu35.configure(state = NORMAL)
        txt_menu35.focus()
        txt_menu35.delete('0', END)
        E_menu35.set("")
    elif (var35.get() == 0):
        txt_menu35.configure(state = DISABLED)
        E_menu35.set('0')
        
def chk_menu36():
    if (var36.get() == 1):
        txt_menu36.configure(state = NORMAL)
        txt_menu36.focus()
        txt_menu36.delete('0', END)
        E_menu36.set("")
    elif (var36.get() == 0):
        txt_menu36.configure(state = DISABLED)
        E_menu36.set('0')

def chk_menu101():
    if (var101.get() == 1):
        txt_menu101.configure(state = NORMAL)
        txt_menu101.focus()
        txt_menu101.delete('0', END)
        E_menu101.set("")
    elif (var101.get() == 0):
        txt_menu101.configure(state = DISABLED)
        E_menu101.set('0')
        
def chk_menu102():
    if (var102.get() == 1):
        txt_menu102.configure(state = NORMAL)
        txt_menu102.focus()
        txt_menu102.delete('0', END)
        E_menu102.set("")
    elif (var102.get() == 0):
        txt_menu102.configure(state = DISABLED)
        E_menu102.set('0')
        
def chk_menu103():
    if (var103.get() == 1):
        txt_menu103.configure(state = NORMAL)
        txt_menu103.focus()
        txt_menu103.delete('0', END)
        E_menu103.set("")
    elif (var103.get() == 0):
        txt_menu103.configure(state = DISABLED)
        E_menu103.set('0')
        
def chk_menu104():
    if (var104.get() == 1):
        txt_menu104.configure(state = NORMAL)
        txt_menu104.focus()
        txt_menu104.delete('0', END)
        E_menu104.set("")
    elif (var104.get() == 0):
        txt_menu104.configure(state = DISABLED)
        E_menu104.set('0')
        
def chk_menu105():
    if (var105.get() == 1):
        txt_menu105.configure(state = NORMAL)
        txt_menu105.focus()
        txt_menu105.delete('0', END)
        E_menu105.set("")
    elif (var105.get() == 0):
        txt_menu105.configure(state = DISABLED)
        E_menu105.set('0')
        
def chk_menu106():
    if (var106.get() == 1):
        txt_menu106.configure(state = NORMAL)
        txt_menu106.focus()
        txt_menu106.delete('0', END)
        E_menu106.set("")
    elif (var106.get() == 0):
        txt_menu106.configure(state = DISABLED)
        E_menu106.set('0')
        
def chk_menu107():
    if (var107.get() == 1):
        txt_menu107.configure(state = NORMAL)
        txt_menu107.focus()
        txt_menu107.delete('0', END)
        E_menu107.set("")
    elif (var107.get() == 0):
        txt_menu107.configure(state = DISABLED)
        E_menu107.set('0')
        
def chk_menu108():
    if (var108.get() == 1):
        txt_menu108.configure(state = NORMAL)
        txt_menu108.focus()
        txt_menu108.delete('0', END)
        E_menu108.set("")
    elif (var108.get() == 0):
        txt_menu108.configure(state = DISABLED)
        E_menu108.set('0')
        
def chk_menu109():
    if (var109.get() == 1):
        txt_menu109.configure(state = NORMAL)
        txt_menu109.focus()
        txt_menu109.delete('0', END)
        E_menu109.set("")
    elif (var109.get() == 0):
        txt_menu109.configure(state = DISABLED)
        E_menu109.set('0')
        
def chk_menu110():
    if (var110.get() == 1):
        txt_menu110.configure(state = NORMAL)
        txt_menu110.focus()
        txt_menu110.delete('0', END)
        E_menu110.set("")
    elif (var110.get() == 0):
        txt_menu110.configure(state = DISABLED)
        E_menu110.set('0')
        
def chk_menu111():
    if (var111.get() == 1):
        txt_menu111.configure(state = NORMAL)
        txt_menu111.focus()
        txt_menu111.delete('0', END)
        E_menu111.set("")
    elif (var111.get() == 0):
        txt_menu111.configure(state = DISABLED)
        E_menu111.set('0')
        
def chk_menu112():
    if (var112.get() == 1):
        txt_menu112.configure(state = NORMAL)
        txt_menu112.focus()
        txt_menu112.delete('0', END)
        E_menu112.set("")
    elif (var112.get() == 0):
        txt_menu112.configure(state = DISABLED)
        E_menu112.set('0')
        
        

# def iReceipt():
#     txtReceipt.delete("1.0",END)
#     x = random.randint(10903,500876)
#     randomRef = str(x)
#     Receipt_Ref.set('BILL' + randomRef)

#     txtReceipt.insert(END, 'Receipt Ref:\t\t\t' + Receipt_Ref.get() + '\t' + DateofOrder.get() + '\n')
#     txtReceipt.insert(END, 'Item:\t\t\t' + "\n"
#     txtReceipt.insert(END, 'menu1: \t\t\t\t\t\t\t\t\t\t\t\t\t' + E_menu1 )
#     txtReceipt.insert(END, 'menu2 Ref:\t\t\t\t\t\t\t\t\t' + E_menu2.get()+ "\n")
#     txtReceipt.insert(END, 'menu3 Ref:\t\t\t\t\t\t\t\t\t' + E_menu3.get()+ "\n")
#     txtReceipt.insert(END, 'menu4 Ref:\t\t\t\t\t\t\t\t\t' + E_menu4.get()+ "\n")
#     txtReceipt.insert(END, 'menu5 Ref:\t\t\t\t\t\t\t\t\t' + E_menu5.get()+ "\n")
#     txtReceipt.insert(END, 'menu6 Ref:\t\t\t\t\t\t\t\t\t' + E_menu6.get()+ "\n")
#     txtReceipt.insert(END, 'menu7 Ref:\t\t\t\t\t\t\t\t\t' + E_menu7.get()+ "\n")
#     txtReceipt.insert(END, 'menu8 Ref:\t\t\t\t\t\t\t\t\t' + E_menu8.get()+ "\n")
#     txtReceipt.insert(END, 'menu9 Ref:\t\t\t\t\t\t\t\t\t' + E_menu9.get()+ "\n")
#     txtReceipt.insert(END, 'menu10 Ref:\t\t\t\t\t\t\t\t\t' + E_menu10.get()+ "\n")
#     txtReceipt.insert(END, 'menu11 Ref:\t\t\t\t\t\t\t\t\t' + E_menu11.get()+ "\n")
#     txtReceipt.insert(END, 'menu12 Ref:\t\t\t\t\t\t\t\t\t' + E_menu12.get()+ "\n")
#     txtReceipt.insert(END, 'menu13 Ref:\t\t\t\t\t\t\t\t\t' + E_menu13.get()+ "\n")
#     txtReceipt.insert(END, 'menu14 Ref:\t\t\t\t\t\t\t\t\t' + E_menu14.get()+ "\n")
#     txtReceipt.insert(END, 'menu15 Ref:\t\t\t\t\t\t\t\t\t' + E_menu15.get()+ "\n")
#     txtReceipt.insert(END, 'menu16 Ref:\t\t\t\t\t\t\t\t\t' + E_menu16.get()+ "\n")
#     txtReceipt.insert(END, 'menu17 Ref:\t\t\t\t\t\t\t\t\t' + E_menu17.get()+ "\n")
#     txtReceipt.insert(END, 'menu18 Ref:\t\t\t\t\t\t\t\t\t' + E_menu18.get()+ "\n")
#     txtReceipt.insert(END, 'menu19 Ref:\t\t\t\t\t\t\t\t\t' + E_menu19.get()+ "\n")
#     txtReceipt.insert(END, 'menu20 Ref:\t\t\t\t\t\t\t\t\t' + E_menu20.get()+ "\n")
#     txtReceipt.insert(END, 'menu21 Ref:\t\t\t\t\t\t\t\t\t' + E_menu21.get()+ "\n")
#     txtReceipt.insert(END, 'menu22 Ref:\t\t\t\t\t\t\t\t\t' + E_menu22.get()+ "\n")
#     txtReceipt.insert(END, 'menu23 Ref:\t\t\t\t\t\t\t\t\t' + E_menu23.get()+ "\n")
#     txtReceipt.insert(END, 'menu24 Ref:\t\t\t\t\t\t\t\t\t' + E_menu24.get()+ "\n")
#     txtReceipt.insert(END, 'menu25 Ref:\t\t\t\t\t\t\t\t\t' + E_menu25.get()+ "\n")
#     txtReceipt.insert(END, 'menu26 Ref:\t\t\t\t\t\t\t\t\t' + E_menu26.get()+ "\n")
#     txtReceipt.insert(END, 'menu27 Ref:\t\t\t\t\t\t\t\t\t' + E_menu27.get()+ "\n")
#     txtReceipt.insert(END, 'menu28 Ref:\t\t\t\t\t\t\t\t\t' + E_menu28.get()+ "\n")
#     txtReceipt.insert(END, 'menu29 Ref:\t\t\t\t\t\t\t\t\t' + E_menu29.get()+ "\n")
#     txtReceipt.insert(END, 'menu30 Ref:\t\t\t\t\t\t\t\t\t' + E_menu30.get()+ "\n")
#     txtReceipt.insert(END, 'menu31 Ref:\t\t\t\t\t\t\t\t\t' + E_menu31.get()+ "\n")
#     txtReceipt.insert(END, 'menu32 Ref:\t\t\t\t\t\t\t\t\t' + E_menu32.get()+ "\n")
#     txtReceipt.insert(END, 'menu33 Ref:\t\t\t\t\t\t\t\t\t' + E_menu33.get()+ "\n")
#     txtReceipt.insert(END, 'menu34 Ref:\t\t\t\t\t\t\t\t\t' + E_menu34.get()+ "\n")
#     txtReceipt.insert(END, 'menu35 Ref:\t\t\t\t\t\t\t\t\t' + E_menu35.get()+ "\n")
#     txtReceipt.insert(END, 'menu36 Ref:\t\t\t\t\t\t\t\t\t' + E_menu36.get()+ "\n")
#     txtReceipt.insert(END, 'menu101 Ref:\t\t\t\t\t\t\t\t\t' + E_menu101.get()+"\n")
#     txtReceipt.insert(END, 'menu102 Ref:\t\t\t\t\t\t\t\t\t' + E_menu102.get()+"\n")
#     txtReceipt.insert(END, 'menu103 Ref:\t\t\t\t\t\t\t\t\t' + E_menu103.get()+"\n")
#     txtReceipt.insert(END, 'menu104 Ref:\t\t\t\t\t\t\t\t\t' + E_menu104.get()+"\n")
#     txtReceipt.insert(END, 'menu105 Ref:\t\t\t\t\t\t\t\t\t' + E_menu105.get()+"\n")
#     txtReceipt.insert(END, 'menu106 Ref:\t\t\t\t\t\t\t\t\t' + E_menu106.get()+"\n")
#     txtReceipt.insert(END, 'menu107 Ref:\t\t\t\t\t\t\t\t\t' + E_menu107.get()+"\n")
#     txtReceipt.insert(END, 'menu108 Ref:\t\t\t\t\t\t\t\t\t' + E_menu108.get()+"\n")
#     txtReceipt.insert(END, 'menu109 Ref:\t\t\t\t\t\t\t\t\t' + E_menu109.get()+"\n")
#     txtReceipt.insert(END, 'menu110 Ref:\t\t\t\t\t\t\t\t\t' + E_menu110.get()+"\n")
#     txtReceipt.insert(END, 'menu111 Ref:\t\t\t\t\t\t\t\t\t' + E_menu111.get()+"\n")
#     txtReceipt.insert(END, 'menu102 Ref:\t\t\t\t\t\t\t\t\t' + E_menu112.get()+"\n")
#     txtReceipt.insert(END, '\nSubTotal:\t\t\t\t\t\t\t\t\t\t' + str(SubTotal.get()) + '\n')
#     txtReceipt.insert(END, '\nTotal Cost:\t\t\t\t\t\t\t\t\t\t' + str(TotalCost.get()) + '\n')


#=========================== FRAMES =========================== 
ColumnFrame_1=Frame(MenuFrame, bg='Powder Blue', bd=10, relief=RIDGE)
ColumnFrame_1.pack(side=LEFT)

ColumnFrame_2=Frame(MenuFrame, bg='Powder Blue', bd=10, relief=RIDGE)
ColumnFrame_2.pack(side=LEFT)

ColumnFrame_3=Frame(MenuFrame, bg='Powder Blue', bd=10, relief=RIDGE)
ColumnFrame_3.pack(side=RIGHT)

#========================= Entradas ========================= 
var1=IntVar()
menu1 = Checkbutton(ColumnFrame_1, text='1. Lumpia', variable=var1, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu1).grid(row=0, sticky=W)
var2=IntVar()
menu2 = Checkbutton(ColumnFrame_1, text='2. Langostinos Fritos', variable=var2, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu2).grid(row=1, sticky=W)
var3=IntVar()
menu3 = Checkbutton(ColumnFrame_1, text='3. Camarones Fritos', variable=var3, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu3).grid(row=2, sticky=W)
var4=IntVar()
menu4 = Checkbutton(ColumnFrame_1, text='4. Coctel de Langostinos', variable=var4, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu4).grid(row=3, sticky=W)
var5=IntVar()
menu5 = Checkbutton(ColumnFrame_1, text='5. Coctel de Camarones', variable=var5, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu5).grid(row=4, sticky=W)
var6=IntVar()
menu6 = Checkbutton(ColumnFrame_1, text='6. Papas Fritas', variable=var6, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu6).grid(row=5, sticky=W)
var7=IntVar()
menu7 = Checkbutton(ColumnFrame_1, text='7. Costillas Fritas', variable=var7, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu7).grid(row=6, sticky=W)
var8=IntVar()
menu8 = Checkbutton(ColumnFrame_1, text='8. Muslitos Fritos', variable=var8, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu8).grid(row=7, sticky=W)

#========================= Arroz Chino ========================= 
var20=IntVar()
menu20 = Checkbutton(ColumnFrame_2, text='ArrozChino 7 Carnes', variable=var20, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command=chk_menu20).grid(row=0, sticky=W)
var21=IntVar()
menu21 = Checkbutton(ColumnFrame_2, text='ArrozChino 3 Carnes', variable=var21, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu21).grid(row=1, sticky=W)
var22=IntVar()
menu22 = Checkbutton(ColumnFrame_2, text='ArrozChino con Camarones', variable=var22, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu22).grid(row=2, sticky=W)
var23=IntVar()
menu23 = Checkbutton(ColumnFrame_2, text='ArrozChino con Mariscos', variable=var23, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu23).grid(row=3, sticky=W)
var24=IntVar()
menu24 = Checkbutton(ColumnFrame_2, text='ArrozChino Pollo y Camaron', variable=var24, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu24).grid(row=4, sticky=W)
var25=IntVar()
menu25 = Checkbutton(ColumnFrame_2, text='ArrozChino con Pollo', variable=var25, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu25).grid(row=5, sticky=W)
var26=IntVar()
menu26 = Checkbutton(ColumnFrame_2, text='ArrozChino 4 Carnes', variable=var26, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu26).grid(row=6, sticky=W)
var27=IntVar()
menu27 = Checkbutton(ColumnFrame_2, text='ArrozChino a la Valenciana', variable=var27, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu27).grid(row=7, sticky=W)
var28=IntVar()
menu28 = Checkbutton(ColumnFrame_2, text='ArrozChino con Langostinos', variable=var28, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu28).grid(row=8, sticky=W)

#========================= Chop Suey ========================= 

var29=IntVar()
menu29 = Checkbutton(ColumnFrame_2, text='ChopSuey Especial', variable=var29, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu29).grid(row=9, sticky=W)
var30=IntVar()
menu30 = Checkbutton(ColumnFrame_2, text='ChopSuey con Pollo', variable=var30, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu30).grid(row=10, sticky=W)
var31=IntVar()
menu31 = Checkbutton(ColumnFrame_2, text='ChopSuey con camarones', variable=var31, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu31).grid(row=11, sticky=W)
var32=IntVar()
menu32 = Checkbutton(ColumnFrame_2, text='ChopSuey con langostinos', variable=var32, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu32).grid(row=12, sticky=W)
var33=IntVar()
menu33 = Checkbutton(ColumnFrame_2, text='ChopSuey con carne', variable=var33, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu33).grid(row=13, sticky=W)
var34=IntVar()
menu34 = Checkbutton(ColumnFrame_2, text='ChopSuey con mariscos', variable=var34, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu34).grid(row=14, sticky=W)
var35=IntVar()
menu35 = Checkbutton(ColumnFrame_2, text='ChopSuey pollo y camaron', variable=var35, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu35).grid(row=15, sticky=W)
var36=IntVar()
menu36 = Checkbutton(ColumnFrame_2, text='ChopSuey solo vegetales', variable=var36, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu36).grid(row=16, sticky=W)
#========================= Combos Personales ========================= 

var101=IntVar()
menu101 = Checkbutton(ColumnFrame_3, text='Combo 101', variable=var101, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu101).grid(row=0, sticky=W)
var102=IntVar()
menu102 = Checkbutton(ColumnFrame_3, text='Combo 102', variable=var102, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu102).grid(row=1, sticky=W)
var103=IntVar()
menu103 = Checkbutton(ColumnFrame_3, text='Combo 103', variable=var103, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu103).grid(row=2, sticky=W)
var104=IntVar()
menu104 = Checkbutton(ColumnFrame_3, text='Combo 104', variable=var104, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu104).grid(row=3, sticky=W)
var105=IntVar()
menu105 = Checkbutton(ColumnFrame_3, text='Combo 105', variable=var105, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu105).grid(row=4, sticky=W)
var106=IntVar()
menu106 = Checkbutton(ColumnFrame_3, text='Combo 106', variable=var106, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu106).grid(row=5, sticky=W)
var107=IntVar()
menu107 = Checkbutton(ColumnFrame_3, text='Combo 107', variable=var107, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu107).grid(row=6, sticky=W)
var108=IntVar()
menu108 = Checkbutton(ColumnFrame_3, text='Combo 108', variable=var108, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu108).grid(row=7, sticky=W)
var109=IntVar()
menu109 = Checkbutton(ColumnFrame_3, text='Combo 109', variable=var109, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu109).grid(row=8, sticky=W)
var110=IntVar()
menu110 = Checkbutton(ColumnFrame_3, text='Combo 110', variable=var110, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu110).grid(row=9, sticky=W)
var111=IntVar()
menu111 = Checkbutton(ColumnFrame_3, text='Combo 111', variable=var111, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu111).grid(row=10, sticky=W)
var112=IntVar()
menu112 = Checkbutton(ColumnFrame_3, text='Combo 112', variable=var112, onvalue=1, offvalue=0, font=('arial', 18, 'bold'),
                   bg='Powder Blue', command = chk_menu112).grid(row=11, sticky=W)

#===============================================================
#===================== Entry Box for Entradas =====================

txt_menu1 = Entry(ColumnFrame_1, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu1)
txt_menu1.grid(row=0,column=1)

txt_menu2 = Entry(ColumnFrame_1, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu2)
txt_menu2.grid(row=1,column=1)

txt_menu3 = Entry(ColumnFrame_1, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu3)
txt_menu3.grid(row=2,column=1)

txt_menu4 = Entry(ColumnFrame_1, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu4)
txt_menu4.grid(row=3,column=1)

txt_menu5 = Entry(ColumnFrame_1, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu5)
txt_menu5.grid(row=4,column=1)

txt_menu6 = Entry(ColumnFrame_1, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu6)
txt_menu6.grid(row=5,column=1)

txt_menu7 = Entry(ColumnFrame_1, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu7)
txt_menu7.grid(row=6,column=1)

txt_menu8 = Entry(ColumnFrame_1, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu8)
txt_menu8.grid(row=7,column=1)

#===================== Entry Box for Arroz =====================

txt_menu20 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu20)
txt_menu20.grid(row=0,column=1)

txt_menu21 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu21)
txt_menu21.grid(row=1,column=1)

txt_menu22 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu22)
txt_menu22.grid(row=2,column=1)

txt_menu23 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu23)
txt_menu23.grid(row=3,column=1)

txt_menu24 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu24)
txt_menu24.grid(row=4,column=1)

txt_menu25 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu25)
txt_menu25.grid(row=5,column=1)

txt_menu26 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu26)
txt_menu26.grid(row=6,column=1)

txt_menu27 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu27)
txt_menu27.grid(row=7,column=1)

txt_menu28 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu28)
txt_menu28.grid(row=8,column=1)

#===================== Entry Box for ChopSuey ======================
txt_menu29 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu29)
txt_menu29.grid(row=9,column=1)

txt_menu30 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu30)
txt_menu30.grid(row=10,column=1)

txt_menu31 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu31)
txt_menu31.grid(row=11,column=1)

txt_menu32 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu32)
txt_menu32.grid(row=12,column=1)

txt_menu33 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu33)
txt_menu33.grid(row=13,column=1)

txt_menu34 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu34)
txt_menu34.grid(row=14,column=1)

txt_menu35 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu35)
txt_menu35.grid(row=15,column=1)

txt_menu36 = Entry(ColumnFrame_2, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu36)
txt_menu36.grid(row=16,column=1)

#===================== Entry Box for Combos Personales =====================
txt_menu101 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu101)
txt_menu101.grid(row=0,column=1)

txt_menu102 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu102)
txt_menu102.grid(row=1,column=1)

txt_menu103 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu103)
txt_menu103.grid(row=2,column=1)

txt_menu104 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu104)
txt_menu104.grid(row=3,column=1)

txt_menu105 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu105)
txt_menu105.grid(row=4,column=1)

txt_menu106 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu106)
txt_menu106.grid(row=5,column=1)

txt_menu107 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu107)
txt_menu107.grid(row=6,column=1)

txt_menu108 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu108)
txt_menu108.grid(row=7,column=1)

txt_menu109 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu109)
txt_menu109.grid(row=8,column=1)

txt_menu110 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu110)
txt_menu110.grid(row=9,column=1)

txt_menu111 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu111)
txt_menu111.grid(row=10,column=1)

txt_menu112 = Entry(ColumnFrame_3, font=('arial', 16, 'bold'), bd=8, width=6, justify='left', state=DISABLED, textvariable=E_menu112)
txt_menu112.grid(row=11,column=1)


#===================================================================
#===================== Payment Information  ========================
# Sub Total
lblSubTotal = Label(Cost_F, font=('arial', 14, 'bold'), text="\tSub Total",bd=7, bg='powder Blue', fg='black') 
lblSubTotal.grid(row=0, column=0, sticky=W)

txtSubTotal = Entry(Cost_F, font=('arial', 14, 'bold'), bd=7, bg='white', insertwidth=2, justify=LEFT)
txtSubTotal.grid(row=0, column=1)

# Total Cost
lblTotalCost = Label(Cost_F, font=('arial', 14, 'bold'), text="\tTotal", bd= 7, bg='powder Blue', fg='black') 
lblTotalCost.grid(row=0, column=2, sticky=W)

txtTotalCost = Entry(Cost_F, insertwidth=2, bg='white', bd=7, font=('arial', 14, 'bold'), justify=RIGHT)
txtTotalCost.grid(row=0, column=3)

#=======================  Receipt  ========================

txtReceipt = Text(ReceiptFrame, width=46, height=12, bg='white', bd=4, font=('arial', 12, 'bold'))
txtReceipt.grid(row=0, column=0)

#======================= Buttons  ========================

btnTotal = Button(ButtonsFrame, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='Total', bg='powder blue', command=iCostofItem).grid(row=0, column=0)

btnReceipt = Button(ButtonsFrame, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='Receipt', bg='powder blue').grid(row=0, column=1)

btnReset = Button(ButtonsFrame, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='Reset', bg='powder blue', command=iReset).grid(row=0, column=2)

btnExit = Button(ButtonsFrame, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='Exit', bg='powder blue', command = iExit).grid(row=0, column=3)

#====================== Calculator Display =========================
    
def btnClick(numbers):
    global operator
    operator = operator + str(numbers)
    text_Input.set(operator)
    
def btnClear():
    global operator
    operator = ""
    text_Input.set("")
    
def btnEquals():
    global operator
    sumup = str(eval(operator))
    text_Input.set(sumup)
    operator = ""

txtDisplay = Entry(Cal_F, width=45, bg='white', bd=4, font=('arial', 12, 'bold'), justify=RIGHT, textvariable=text_Input)
txtDisplay.grid(row=0, column=0, columnspan=4, pady=1)
txtDisplay.insert(0, '0')

#======================= Calculator Buttons  ========================

btn7 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='7', bg='powder blue', command=lambda:btnClick(7)).grid(row=2, column=0)

btn8 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='8', bg='powder blue', command=lambda:btnClick(8)).grid(row=2, column=1)

btn9 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='9', bg='powder blue',command=lambda:btnClick(9)).grid(row=2, column=2)

btnAdd = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='+', bg='powder blue',command=lambda:btnClick('+')).grid(row=2, column=3)
#======================= Calculator Buttons  ========================

btn4 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='4',command=lambda:btnClick(4)).grid(row=3, column=0)

btn5 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='5',command=lambda:btnClick(5)).grid(row=3, column=1)

btn6 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='6',command=lambda:btnClick(6)).grid(row=3, column=2)

btnSub = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='-', bg='powder blue',command=lambda:btnClick('-')).grid(row=3, column=3)
#======================= Calculator Buttons  ========================

btn1 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='1',command=lambda:btnClick(1)).grid(row=4, column=0)

btn2 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='2',command=lambda:btnClick(2)).grid(row=4, column=1)

btn3 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='3',command=lambda:btnClick(3)).grid(row=4, column=2)

btnMult = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='*', bg='powder blue',command=lambda:btnClick('*')).grid(row=4, column=3)
#======================= Calculator Buttons  ========================

btn0 = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='0', bg='powder blue',command=lambda:btnClick(0)).grid(row=5, column=0)

btnClear = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='C', bg='powder blue',command=btnClear).grid(row=5, column=1)

btnEquals = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='=', bg='powder blue',command=btnEquals).grid(row=5, column=2)

btnDiv = Button(Cal_F, padx=16,pady=1,bd=7,fg='black',font=('arial', 16, 'bold'), width=4, 
                  text='/', bg='powder blue',command=lambda:btnClick('/')).grid(row=5, column=3)





root.mainloop()
